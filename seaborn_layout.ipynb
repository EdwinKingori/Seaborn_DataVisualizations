# %% [markdown]
# ## Initial Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Importing Data

# %%
# using seaborn's built_in datasets. 
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
#Loading one of the datasets
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
crash_df.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
crash_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
columns = list(crash_df.columns)
print(columns)
# Out:
# ['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous', 'ins_premium', 'ins_losses', 'abbrev']

# %% [markdown]
# # Distribution Plots

# %% [markdown]
# Distribution plot helps to look at univariable disributions: providing a distibution for one variable. Example:
# KDE (Kernel Density Estimation) - estimates the distribution of data. in this case, the curved line.

# %%
sns.set_theme()
sns.distplot(crash_df['not_distracted'], kde = False, bins = 25)
# Out:
# /tmp/ipykernel_5477/187898434.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'], kde = False, bins = 25)
# <AxesSubplot: xlabel='not_distracted'>

# %%
#Checking the difference between distplot and displot function, which is in the update version
sns.displot(crash_df['not_distracted'], kde = False, bins = 25)

# %% [markdown]
# ## Join Plot

# %% [markdown]
# Joint plots are used to exhibit relationships between two variables.
# The central plot in a jointplot is a scatter plot by default,
# but you can also choose other plot types such as hexbin, kernel density estimation, or regression.

# %%
#Generating a regression line using the Kind = "reg"

sns.jointplot(x= "speeding", y = 'alcohol', data = crash_df, kind = 'reg')

# %%
#Generating a kernel density estimation using the Kind = "kde" (estimates the distribution of data)
sns.jointplot(x= "speeding", y = 'alcohol', data = crash_df, kind = 'kde')

# %%
#Generating a hexagon hdistribution using the Kind = "hex"
sns.jointplot(x= "speeding", y = 'alcohol', data = crash_df, kind = 'hex')

# %% [markdown]
# ## KDE Plot

# %%
sns.kdeplot(data = crash_df['alcohol'])
# Out:
# <AxesSubplot: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# ## Pair Plot

# %%
# Pair plot exhibits the relationships across entire d_f numerical values.
sns.pairplot(crash_df)

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips_df, hue = 'sex', palette = "Greens")

# %% [markdown]
# ## Rug Plot

# %% [markdown]
#  Rug plot are used to display a the distribution of a single variable along an axis.
# They are often used in conjunction with other plots, such as histograms or kernel density plots to provide additional insight into the data.

# %%
sns.rugplot(tips_df['tip'])
# Out:
# <AxesSubplot: xlabel='tip'>

# %% [markdown]
# ## Styling

# %%
# Setting styles for axis and grids
 #styles types: white, dark, whitegrid, darkgrid, ticks
sns.set_style('darkgrid')

plt.figure(figsize = (8,4))

# labels and text styling: three options including 'paper', 'talk' and 'poster'
sns.set_context('paper', font_scale = 1.5)

sns.jointplot(x = 'speeding', y = 'alcohol', data =crash_df, kind = 'reg')

# removing spines. Spies are the lines used on the axis
#sns.despine(left = True, bottom = True)

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# Categorical plots help to understand distributions using categorical data in referece to one of the numerical data.
#
#  Seaborn provides several types of categorical plots, such as bar plots, count plots, box plots, violin plots, and more

# %% [markdown]
# ## Bar Plots

# %%
# you can aggregate the date based on the mean, median, STD, var using the estimator varible. 
sns.barplot(data = tips_df, x = 'sex', y = 'total_bill', estimator = np.var)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# ## Count Plot

# %%
# Shift + tab for more info
sns.countplot(data = tips_df, x = 'sex')
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %% [markdown]
# ## Box Plot

# %% [markdown]
# A box plot (or box-and-whisker plot) shows the distribution of quantitative
# data in a way that facilitates comparisons between variables or across
# levels of a categorical variable.
# The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution,
# except for points that are determined to be "outliers" using a method
# that is a function of the inter-quartile range.

# %%
sns.boxplot(data = tips_df, x ='day', y = 'total_bill', hue = 'sex')
plt.legend(loc = 0)

# %% [markdown]
# From the plot above:
#     The barline that goes accross he middle of the boxes is the median, and the box extends one_standard deviation(that's what the box represents) from the median.
# The lines above the boxes are whiskers. And they extend to all of the other data asides from what is in the standaed deviation. The star-like shapes are considered to be outliers.
#
# The inclusion of the hue provides us with the ability to introduce an additional category. In this specific scenario, by incorporating sex as the hue, we are able to generate comparative boxplots for each day, differentiating between males and females.

# %% [markdown]
# ## Violin Plot

# %% [markdown]
# Basically, it's a combination of a boxplot and a KDE plot.

# %%
sns.violinplot(data = tips_df, x = 'day', y = 'total_bill', hue = 'sex', split = True)
# Split is usedd to show how the categories compare to each other.
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Strip Plot

# %% [markdown]
# Strip plots are similar to scatter plots but have only one axis representing the data points. The data points are displayed as individual marks (such as dots or short lines) along the axis, showing their respective values.

# %%
plt.figure(figsize = (8,5))

sns.stripplot(data = tips_df, x = 'day', y = 'total_bill', jitter = True, hue = 'sex', dodge = True )
#Dodge separates the male and female data for each day.
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Swarm Plot

# %% [markdown]
# Data points are plotted as individual markers, typically in a horizontal or vertical orientation, without overlapping.

# %%
sns.violinplot(data = tips_df, x = 'day', y = 'total_bill')
sns.swarmplot(data = tips_df, x = 'day', y = 'total_bill', color = 'black')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(data = tips_df, x = 'day', y = 'total_bill', hue='sex')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ## Palette

# %%
plt.figure(figsize=(8,6))

sns.set_style('dark')
sns.set_context('talk')
sns.stripplot(data = tips_df, x = 'day', y= 'total_bill', hue = 'sex', palette = 'afmhot', dodge = True )

#Legend positions:
    #upper right:1, upper left = 2, lower left:3, lower right:4
plt.legend(loc = 0)

# %% [markdown]
# ## Matrix plots

# %% [markdown]
# ### HeatMaps

# %%
plt.figure(figsize = (8,6))
sns.set_context('paper', font_scale = 1.4)

# Removing the non_numerical columns which in this case is the 'abbrev column'
# The inplace = False parameter is used to avoid modifying the original crash_df.
crash_mx = crash_df.drop(columns = ['abbrev'], inplace = False)

# Getting the correlation matrix between numerical columns of the newly created df. 
new_crash_mx = crash_mx.corr()
new_crash_mx
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
#Creating a heatmap to visualize the correlation of crash_mx df.
sns.heatmap(new_crash_mx, annot=True, cmap = 'Blues')
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Creating a Matrix Using a Pivot Table

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
#Creating a pivot_table from the flights df
flights = flights.pivot_table(index = 'month', columns= 'year', values = 'passengers')
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
#Creatiing a heatmap from the pivot_table
sns.heatmap(flights, cmap = 'Greens', linewidth = 1, linecolor = 'grey' )
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>

# %% [markdown]
# ## Cluster Map

# %% [markdown]
# The clustermap function is used to create a clustered heatmap, which is a heatmap where rows and/or columns are clustered based on their similarity, allowing for patterns and structure in the data to be more easily visualized.
#
# You can pass to You can customize the appearance and behavior of the clustermap using common parameters include *cmap* for specifying the color map, *row_cluster* and *col_cluster* for controlling row and column clustering, *method* for selecting the clustering method, etc.

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Distinguishig the data based on the different species of iris. 
species = iris.pop('species')
#plotting the divided data (a hierachical clustermap)
sns.clustermap(iris)

# %%
sns.clustermap(flights, cmap = 'Blues', standard_scale = 1)

# %% [markdown]
# ## Pair Grid

# %% [markdown]
# The PairGrid allows you to customize each subplot individually, making it a versatile way to visualize various types of data distributions and correlations. It is a high-level interface for creating pair plots, and it uses other Seaborn plotting functions to create the individual subplots.

# %% [markdown]
# The grid.map() function is used to map the type of plot you want to create on the grid. You can use any Seaborn plotting function, such as scatterplot, kdeplot, histplot, etc.

# %%
iris = sns.load_dataset('iris')
iris_df = sns.PairGrid(iris, hue = 'species')
# visualizing the scatterplots diognally and in both the upper na lower sections using the plt.scatter
iris_df.map(plt.scatter)
# putting a histogram across the diognal 
iris_df.map_diag(plt.hist)

# %%
#Placing a scatterplot in the upper grid, a kde plot in the lower grid, and a histogram in the diognal grid  
iris_df = sns.PairGrid(iris, hue = 'species')

# plotting the diognal hist
iris_df.map_diag(plt.hist)

# upper scatter and lower kde
iris_df.map_upper(plt.scatter)
iris_df.map_lower(sns.kdeplot)

# %%
# Creating a custom PairGrid plot
iris_df = sns.PairGrid(iris, hue = 'species', 
                      x_vars = ['sepal_length', 'sepal_width'],
                      y_vars = ['petal_length', 'petal_width'])

iris_df.map(plt.scatter)
iris_df.add_legend()

# %% [markdown]
# ## Facet Grid

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', row = 'smoker')
#Creating a hist plot
tips_fg.map(plt.hist, 'total_bill', bins = 8)

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', row = 'smoker')
#Creating a facetgrid scatterpot
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
tips_fg = sns.FacetGrid(tips_df, col = 'time', hue = 'smoker', height = 4, aspect =1.3, 
                       col_order = ['Dinner', 'Lunch'], palette = 'Set1')
tips_fg.map(plt.scatter, 'total_bill', 'tip')

# %%
kws = dict(s=50, linewidth= .5, edgecolor ='w')
tips_fg = sns.FacetGrid(tips_df, col = 'sex', hue ='smoker', height=4, aspect=1.3, 
                       hue_order = ['Yes', 'No'],
                       hue_kws = dict(marker = ['^', 'v']))
tips_fg.map(plt.scatter, 'total_bill', 'tip', **kws )

# %%
att_df = sns.load_dataset('attention')
att_df.head()
# Out:
#    Unnamed: 0  subject attention  solutions  score
# 0           0        1   divided          1    2.0
# 1           1        2   divided          1    3.0
# 2           2        3   divided          1    3.0
# 3           3        4   divided          1    5.0
# 4           4        5   divided          1    4.0

# %%
att_fg = sns.FacetGrid(att_df, col = 'subject', col_wrap= 5, height=1.5)
att_fg.map(plt.plot, 'solutions', 'score', marker = '.')

# %% [markdown]
# ## Regression Plots

# %% [markdown]
# Regression plots are mainly created using the *regplot* and the *implot* functions.
#
# The *regplot* function creates a scatter plot and fits a linear regression line through the data. It is a standalone function that can be used to create individual regression plots.
#
# The lmplot function creates a FacetGrid and fits a linear regression model to each subset of the data defined by categorical variables. It allows you to create multiple regression plots grouped by categories.

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# example1 : using regplot
sns.regplot(x='total_bill', y='tip', data=tips_df, scatter=True)
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
#Example 2: using implot
sns.lmplot(x='total_bill', y='tip', data=tips_df, hue ='sex', scatter=True)

# %%
# customizing example 2:
plt.figure(figsize =(8,6))
sns.set_context('paper', font_scale = 1.4)
sns.lmplot(x = 'total_bill', y = 'tip', hue = 'sex', data = tips_df, markers =['o', '^'],
          scatter_kws = {'s': 100, 'linewidth': 0.5, 'edgecolor':'w'})

# %%
sns.set_context('paper', font_scale = 1.4)
sns.lmplot(x = 'total_bill', y = 'tip', col = 'sex', row = 'time', data = tips_df, 
          height = 5, aspect = 1.5)
